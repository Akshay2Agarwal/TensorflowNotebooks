# %%
import tensorflow as tf
x = tf.constant([1., 2.])
neg_x = tf.negative(x)
with tf.Session() as sess:
    result = sess.run(neg_x)
print(result)
# Out:
# [-1. -2.]

# %%
#Negative operation example
sess = tf.InteractiveSession()
x = tf.constant([1., 2.])
neg_x = tf.negative(x)
result = neg_x.eval()
print(result)
sess.close()
# Out:
# [-1. -2.]

# %%
#Using a variable
sess = tf.InteractiveSession()
raw_data = [1., 2., 8., 7., 10., 18.]
spike = tf.Variable(False)
spike.initializer.run()
for i in range(1, len(raw_data)):
    if raw_data[i] - raw_data[i-1] > 5:
        updater = tf.assign(spike, True)
        updater.eval()
    else:
        tf.assign(spike, False).eval()
    print("Spike", spike.eval())
sess.close()
# Out:
# Spike False
# Spike True
# Spike False
# Spike False
# Spike True

# %%
# Saving a variable
tf.InteractiveSession().close()
sess = tf.InteractiveSession()
raw_data = [1., 2., 8., 7., 10., 18.]
spikes = tf.Variable([False] * len(raw_data), name='spikes')
spikes.initializer.run()
saver = tf.train.Saver()
for i in range(1, len(raw_data)):
    if raw_data[i] - raw_data[i-1] > 5:
        spikes_val = spikes.eval()
        spikes_val[i] = True
        updater = tf.assign(spikes, spikes_val)
        updater.eval()
save_path = saver.save(sess, "/tmp/spikes.ckpt")
sess.close()
# Out:
# /home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/client/session.py:1702: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# /home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# /home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# /home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# FailedPreconditionError: Attempting to use uninitialized value Variable
# 	 [[{{node save_1/SaveV2}} = SaveV2[dtypes=[DT_BOOL, DT_BOOL, DT_BOOL], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/SaveV2/tensor_names, save_1/SaveV2/shape_and_slices, Variable, spikes, spikes_1)]]
#
# During handling of the above exception, another exception occurred:
#
# FailedPreconditionError                   Traceback (most recent call last)
# <ipython-input-5-c776a89c78ac> in <module>()
#      12         updater = tf.assign(spikes, spikes_val)
#      13         updater.eval()
# ---> 14 save_path = saver.save(sess, "/tmp/spikes.ckpt")
#      15 sess.close()
#
# /home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs)
#    1456               "Parent directory of {} doesn't exist, can't save.".format(
#    1457                   save_path))
# -> 1458         raise exc
#    1459
#    1460     if write_meta_graph:
#
# /home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs)
#    1439           model_checkpoint_path = sess.run(
#    1440               self.saver_def.save_tensor_name,
# -> 1441               {self.saver_def.filename_tensor_name: checkpoint_file})
#    1442
#    1443         model_checkpoint_path = compat.as_str(model_checkpoint_path)
#
# /home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1346           pass
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#    1350   def _extend_graph(self):
#
# FailedPreconditionError: Attempting to use uninitialized value Variable
# 	 [[node save_1/SaveV2 (defined at <ipython-input-5-c776a89c78ac>:7)  = SaveV2[dtypes=[DT_BOOL, DT_BOOL, DT_BOOL], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/SaveV2/tensor_names, save_1/SaveV2/shape_and_slices, Variable, spikes, spikes_1)]]
#
# Caused by op 'save_1/SaveV2', defined at:
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tornado/gen.py", line 1233, in inner
#     self.run()
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2705, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2809, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2869, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-c776a89c78ac>", line 7, in <module>
#     saver = tf.train.Saver()
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1102, in __init__
#     self.build()
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1114, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1151, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 792, in _build_internal
#     save_tensor = self._AddSaveOps(filename_tensor, saveables)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 284, in _AddSaveOps
#     save = self.save_op(filename_tensor, saveables)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 202, in save_op
#     tensors)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1690, in save_v2
#     shape_and_slices=shape_and_slices, tensors=tensors, name=name)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3274, in create_op
#     op_def=op_def)
#   File "/home/akshay.agarwal/anaconda3/envs/TensorflowNotebooks/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1770, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# FailedPreconditionError (see above for traceback): Attempting to use uninitialized value Variable
# 	 [[node save_1/SaveV2 (defined at <ipython-input-5-c776a89c78ac>:7)  = SaveV2[dtypes=[DT_BOOL, DT_BOOL, DT_BOOL], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/SaveV2/tensor_names, save_1/SaveV2/shape_and_slices, Variable, spikes, spikes_1)]]

# %%
#Loading a variable
import tensorflow as tf
sess = tf.InteractiveSession()
spikes = tf.Variable([False] * 7, name='spikes')
#spikes.initializer.run()
#print(spikes.eval())
saver = tf.train.Saver()
saver.restore(sess, "/tmp/spikes.ckpt")
print(spikes.eval())
sess.close()
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/spikes.ckpt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#
# NotFoundError: Key spikes_1 not found in checkpoint
# 	 [[{{node save_1/RestoreV2}} = RestoreV2[dtypes=[DT_BOOL, DT_BOOL], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1545         sess.run(self.saver_def.restore_op_name,
# -> 1546                  {self.saver_def.filename_tensor_name: save_path})
#    1547     except errors.NotFoundError as err:
#
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1347       message = error_interpolation.interpolate(message, self._graph)
# -> 1348       raise type(e)(node_def, op, message)
#    1349
#
# NotFoundError: Key spikes_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-0d3202caf3b0>:7)  = RestoreV2[dtypes=[DT_BOOL, DT_BOOL], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
#
# Caused by op 'save_1/RestoreV2', defined at:
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/asyncio/base_events.py", line 421, in run_forever
#     self._run_once()
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/asyncio/base_events.py", line 1425, in _run_once
#     handle._run()
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/asyncio/events.py", line 127, in _run
#     self._callback(*self._args)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/gen.py", line 1233, in inner
#     self.run()
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2817, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2843, in _run_cell
#     return runner(coro)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3018, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3183, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-0d3202caf3b0>", line 7, in <module>
#     saver = tf.train.Saver()
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1102, in __init__
#     self.build()
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1114, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1151, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 795, in _build_internal
#     restore_sequentially, reshape)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 406, in _AddRestoreOps
#     restore_sequentially)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 862, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1466, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 3274, in create_op
#     op_def=op_def)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1770, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# NotFoundError (see above for traceback): Key spikes_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-0d3202caf3b0>:7)  = RestoreV2[dtypes=[DT_BOOL, DT_BOOL], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
#
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1555       try:
# -> 1556         names_to_keys = object_graph_key_mapping(save_path)
#    1557       except errors.NotFoundError:
#
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py in object_graph_key_mapping(checkpoint_path)
#    1829   object_graph_string = reader.get_tensor(
# -> 1830       checkpointable.OBJECT_GRAPH_PROTO_KEY)
#    1831   object_graph_proto = (
#
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in get_tensor(self, tensor_str)
#     370         return CheckpointReader_GetTensor(self, compat.as_bytes(tensor_str),
# --> 371                                           status)
#     372
#
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-2-0d3202caf3b0> in <module>
#       6 #print(spikes.eval())
#       7 saver = tf.train.Saver()
# ----> 8 saver.restore(sess, "/tmp/spikes.ckpt")
#       9 print(spikes.eval())
#      10 sess.close()
#
# ~/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1560         # a helpful message (b/110263146)
#    1561         raise _wrap_restore_error_with_msg(
# -> 1562             err, "a Variable name or other graph key that is missing")
#    1563
#    1564       # This is an object-based checkpoint. We'll print a warning and then do
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key spikes_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-0d3202caf3b0>:7)  = RestoreV2[dtypes=[DT_BOOL, DT_BOOL], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]
#
# Caused by op 'save_1/RestoreV2', defined at:
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/asyncio/base_events.py", line 421, in run_forever
#     self._run_once()
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/asyncio/base_events.py", line 1425, in _run_once
#     handle._run()
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/asyncio/events.py", line 127, in _run
#     self._callback(*self._args)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/gen.py", line 1233, in inner
#     self.run()
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2817, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2843, in _run_cell
#     return runner(coro)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3018, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3183, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/home/akshay.agarwal/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-0d3202caf3b0>", line 7, in <module>
#     saver = tf.train.Saver()
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1102, in __init__
#     self.build()
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1114, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1151, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 795, in _build_internal
#     restore_sequentially, reshape)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 406, in _AddRestoreOps
#     restore_sequentially)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 862, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1466, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 3274, in create_op
#     op_def=op_def)
#   File "/home/akshay.agarwal/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1770, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# NotFoundError (see above for traceback): Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key spikes_1 not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at <ipython-input-2-0d3202caf3b0>:7)  = RestoreV2[dtypes=[DT_BOOL, DT_BOOL], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_1/Const_0_0, save_1/RestoreV2/tensor_names, save_1/RestoreV2/shape_and_slices)]]

# %%
#Exponential Average Algorithm
import tensorflow as tf
import numpy as np

raw_data = np.random.normal(10, 1, 100)

alpha = tf.constant(0.05)
curr_value =tf.placeholder(tf.float32)
prev_avg = tf.Variable(0.)
update_avg = alpha * curr_value + (1 - alpha) * prev_avg

init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    for i in range(len(raw_data)):
        curr_avg = sess.run(update_avg, feed_dict={curr_value: raw_data[i]})
        sess.run(tf.assign(prev_avg, curr_avg))
        print(raw_data[i], curr_avg)
# Out:
# 9.12050347472 0.456025
# 12.0505159116 1.03575
# 8.42671832541 1.4053
# 12.1896423111 1.94452
# 11.7914593753 2.43686
# 9.50991259348 2.79052
# 8.49165158628 3.07557
# 10.0951046411 3.42655
# 10.4465585483 3.77755
# 10.5423405934 4.11579
# 8.32085847753 4.32604
# 10.5189207004 4.63569
# 11.1856072163 4.96318
# 9.96497713353 5.21327
# 8.65794230288 5.38551
# 9.71539256295 5.602
# 9.87396800607 5.8156
# 8.83864991668 5.96675
# 8.91253586576 6.11404
# 10.5292913946 6.3348
# 11.1616766636 6.57615
# 9.83634721728 6.73916
# 9.83770189915 6.89408
# 10.4150372068 7.07013
# 10.1169559103 7.22247
# 9.6100179391 7.34185
# 10.5958319589 7.50455
# 11.9775133132 7.7282
# 10.5481561584 7.8692
# 12.7218873199 8.11183
# 9.15987523488 8.16423
# 10.6523375013 8.28864
# 9.94736619573 8.37157
# 9.73102949184 8.43955
# 11.3538387172 8.58526
# 10.283397758 8.67017
# 10.0632075447 8.73982
# 8.99607355647 8.75263
# 9.26139246049 8.77807
# 9.88688259592 8.83351
# 9.65753708018 8.87471
# 9.26389357236 8.89417
# 10.2717200997 8.96305
# 9.24795696849 8.97729
# 8.87192134012 8.97202
# 9.15624736772 8.98123
# 10.1553300898 9.03994
# 10.3831639348 9.1071
# 10.8643050439 9.19496
# 8.89161512088 9.17979
# 10.4635331213 9.24398
# 11.5501089723 9.35929
# 12.209422594 9.50179
# 10.4490387799 9.54916
# 10.1626110868 9.57983
# 11.2106481087 9.66137
# 9.3578050734 9.64619
# 10.3781715444 9.68279
# 9.59670447822 9.67849
# 9.72128274359 9.68062
# 11.0235620088 9.74777
# 7.64313582453 9.64254
# 9.98486289387 9.65965
# 10.9302896884 9.72319
# 9.92866541544 9.73346
# 8.97716481706 9.69565
# 10.2618173185 9.72395
# 11.5601753857 9.81577
# 9.63894651817 9.80692
# 10.9177250243 9.86246
# 9.1000158369 9.82434
# 10.0526369142 9.83576
# 9.10764063598 9.79935
# 9.42978026949 9.78087
# 8.44181996231 9.71392
# 8.85300100309 9.67087
# 9.60213721116 9.66744
# 10.241594828 9.69615
# 9.6341493736 9.69305
# 10.1672877583 9.71676
# 11.3672206177 9.79928
# 10.8024744091 9.84944
# 11.1592370611 9.91493
# 8.09521622391 9.82394
# 10.0117677712 9.83333
# 9.97856530278 9.8406
# 9.62451006361 9.82979
# 8.80015013101 9.77831
# 9.71521749233 9.77516
# 10.8901818793 9.83091
# 10.2136013933 9.85004
# 10.3789012567 9.87648
# 9.93716371564 9.87952
# 9.46280697773 9.85868
# 8.62285809151 9.79689
# 10.5189005179 9.83299
# 8.76495130646 9.77959
# 11.6264385094 9.87193
# 9.2683362267 9.84175
# 9.10080932873 9.8047
